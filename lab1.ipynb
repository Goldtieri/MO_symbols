# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_path = 'D:\ММО\lab1\lab1.xlsx'
data = pd.read_excel(data_path);

# %%
x = data['konec']
y = data['uzel']
colors = data['class'].map({'first': 'red', 'second': 'blue', 'third': 'green'})

# %%
plt.scatter(x, y, c=colors)
plt.xlabel('Количество концов')
plt.ylabel('Количество узлов')
# Out:
# Text(0, 0.5, 'Количество узлов')
